# %%
from ecell4 import *
from ecell4.extra import ensemble

def wrap(job,job_id,task_id):
    import time
    def singlerun(a):
        time.sleep(5)
        return 
    out=singlerun(**job)
    return 

jobs=[{'a':2}]
simrun=400
res=ensemble.run_slurm(wrap,jobs,n=simrun,nproc=280,path='tmp',modules=('numpy','ecell4','math'))[0]
print('finish')
# Out:
# DEBUG:sge:Submitted batch job 1221042
# DEBUG:sge:             JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
# DEBUG:sge:1221042_[1-400%280      defq sge-mwmt     chew PD       0:00      1 (None)
# DEBUG:sge:
# INFO:sge:Job 1221042 must be queued, running or being transferred
# INFO:sge:Waiting for jobids [1221042] to finish
# DEBUG:sge:             JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
# DEBUG:sge:1221042_[398-400%2      defq sge-mwmt     chew PD       0:00      1 (JobArrayTaskLimit)
# DEBUG:sge:       1221042_123      defq sge-mwmt     chew  R       0:04      1 ibc08
# DEBUG:sge:       1221042_124      defq sge-mwmt     chew  R       0:04      1 ibc08
# DEBUG:sge:       1221042_125      defq sge-mwmt     chew  R       0:04      1 ibc08
# DEBUG:sge:       1221042_126      defq sge-mwmt     chew  R       0:04      1 ibc08
# DEBUG:sge:       1221042_127      defq sge-mwmt     chew  R       0:04      1 ibc08
# ...
