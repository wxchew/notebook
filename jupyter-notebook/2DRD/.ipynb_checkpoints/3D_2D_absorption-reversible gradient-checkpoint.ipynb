# %%
from ecell4 import *
# %matplotlib inline
import numpy as np
import math
import sys
from math import sqrt
import matplotlib.pyplot as plt
from ecell4.extra import ensemble
import numpy as np
from math import pi

def wrap(job,job_id,task_id):
    def singlerun(ka,kd,NA,L,run,duration,rm):
        import numpy as np
        D=1
        rng = GSLRandomNumberGenerator()
        rng.seed(run)   
        voxelr=rm    
        td =(2*voxelr)**2/(6*D)
        ori = Real3(0.5*L*2,0,0)
        unit0 = Real3(0,0,L)
        unit1 = Real3(0,L,0)        
        w = spatiocyte.SpatiocyteWorld(Real3(L*2,L,L),voxelr,rng)
        size=tuple(w.calculate_shape(Real3(L*2,L,L),voxelr))
        lx,ly,lz=w.actual_lengths()
        Ns = size[1]*size[2]
        Area= ly*lz
        V=ly*lz*lx
        if run==1:
            print('actual A {}, V{},Ns{},td{}'.format(Area,V,Ns,td))
        w.add_structure(Species('M'),PlanarSurface(ori,unit0,unit1))
        with species_attributes():
            A |  {'D': str(D), 'radius':str(voxelr)}
            B |  {'D': str(D), 'radius':str(voxelr),'location':'M'}

        with reaction_rules():#for spa and egfrd
            A + M > B | ka
            #B > A |kd
            #A+M>M | ka

        m2 = get_model()
        w.bind_to(m2)
        
        
        w.add_molecules(Species('A'), NA)
        sim = spatiocyte.SpatiocyteSimulator(w)
        sim.initialize()
        obs=FixedIntervalNumberObserver(td*500,['A'])
        sim.run(duration,obs)        
        tlogs,nalog=np.array(obs.data()).T
        return tlogs,nalog,V,Area,Ns
    job.update({'run':task_id})
    out=singlerun(**job)
    return out


L=4**(1./3)#2.
dur=0.2
NA = 400
rm=0.005
simrun = 100
ka=10

TT=[]
NTs=[]
Vs = []
As=[]
Nss=[]
Stds=[]
print('ka',ka,'Na',NA)
rms=[0.005]
kd=20
#for ka in kas:
for rm in rms:
    jobs = [{'ka':ka,'kd':kd,'NA':NA,'L':L,'duration':dur,'rm':rm}]
    #res=ensemble.run_multiprocessing(wrap,jobs,n=simrun,nproc=60,modules=('numpy','ecell4','math'))[0]
    res=ensemble.run_slurm(wrap,jobs,n=simrun,nproc=500,path='tmp',modules=('numpy','ecell4','math'),extra_args=['--exclude=ibc[02,12,27]'])[0]
    res = np.array(res)
    T = res.T[0][0]
    Nt = np.mean(res.T[1])
    std = np.std(res.T[1])
    Vs.append(res.T[2][0])
    As.append(res.T[3][0])
    Nss.append(res.T[4][0])
    TT.append(T)
    NTs.append(Nt)
    Stds.append(std)
print('finish')
# Out:
# DEBUG:sge:Submitted batch job 2981473
# DEBUG:sge:             JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
# DEBUG:sge:2981473_[1-100%500     debug sge-1wfy     chew PD       0:00      1 (None)
# DEBUG:sge:           2754893     debug job_01.s    niina  R 9-02:40:23      1 ibc01
# DEBUG:sge:           2754894     debug job_08.s    niina  R 9-02:40:23      1 ibc01
# DEBUG:sge:           2754895     debug job_09.s    niina  R 9-02:40:23      1 ibc01
# DEBUG:sge:           2754897     debug job_16.s    niina  R 9-02:40:23      1 ibc01
# DEBUG:sge:           2762398     debug plane_01    niina  R 9-00:40:56      1 ibc04
# DEBUG:sge:           2762399     debug plane_02    niina  R 9-00:40:56      1 ibc04
# DEBUG:sge:           2762400     debug plane_03    niina  R 9-00:40:56      1 ibc06
# DEBUG:sge:           2762401     debug plane_04    niina  R 9-00:40:56      1 ibc06
# DEBUG:sge:           2762402     debug plane_05    niina  R 9-00:40:56      1 ibc06
# DEBUG:sge:           2762403     debug plane_06    niina  R 9-00:40:56      1 ibc19
# DEBUG:sge:           2762404     debug plane_07    niina  R 9-00:40:56      1 ibc19
# DEBUG:sge:           2762405     debug plane_08    niina  R 9-00:40:56      1 ibc19
# DEBUG:sge:           2762406     debug plane_09    niina  R 9-00:40:56      1 ibc18
# DEBUG:sge:           2762407     debug plane_10    niina  R 9-00:40:56      1 ibc18
# DEBUG:sge:           2762408     debug plane_11    niina  R 9-00:40:56      1 ibc18
# DEBUG:sge:           2762409     debug plane_12    niina  R 9-00:40:56      1 ibc18
# DEBUG:sge:           2762411     debug plane_14    niina  R 9-00:40:56      1 ibc18
# DEBUG:sge:           2762412     debug plane_15    niina  R 9-00:40:56      1 ibc18
# DEBUG:sge:           2762413     debug plane_16    niina  R 9-00:40:56      1 ibc17
# DEBUG:sge:           2765414     debug plane_17    niina  R 9-00:10:23      1 ibc18
# DEBUG:sge:           2765415     debug plane_18    niina  R 9-00:10:23      1 ibc18
# DEBUG:sge:           2765416     debug plane_19    niina  R 9-00:10:23      1 ibc18
# DEBUG:sge:           2765417     debug plane_20    niina  R 9-00:10:23      1 ibc18
# DEBUG:sge:           2765418     debug plane_21    niina  R 9-00:10:23      1 ibc18
# DEBUG:sge:           2765419     debug plane_22    niina  R 9-00:10:23      1 ibc18
# DEBUG:sge:           2765420     debug plane_23    niina  R 9-00:10:23      1 ibc18
# DEBUG:sge:           2765421     debug plane_24    niina  R 9-00:10:22      1 ibc18
# DEBUG:sge:           2765422     debug plane_25    niina  R 9-00:10:22      1 ibc18
# DEBUG:sge:           2765423     debug plane_26    niina  R 9-00:10:22      1 ibc19
# DEBUG:sge:           2765424     debug plane_27    niina  R 9-00:10:22      1 ibc19
# DEBUG:sge:           2765425     debug plane_28    niina  R 9-00:10:22      1 ibc19
# DEBUG:sge:           2765426     debug plane_29    niina  R 9-00:10:22      1 ibc19
# DEBUG:sge:           2765427     debug plane_30    niina  R 9-00:10:22      1 ibc19
# DEBUG:sge:           2765428     debug plane_31    niina  R 9-00:10:22      1 ibc19
# DEBUG:sge:           2765429     debug plane_32    niina  R 9-00:10:22      1 ibc19
# DEBUG:sge:           2765430     debug  re01.sh    niina  R 8-23:36:39      1 ibc19
# DEBUG:sge:           2765431     debug  re08.sh    niina  R 8-23:36:33      1 ibc19
# DEBUG:sge:           2765432     debug  re09.sh    niina  R 8-23:36:30      1 ibc19
# DEBUG:sge:           2765433     debug  re14.sh    niina  R 8-23:36:27      1 ibc19
# DEBUG:sge:           2765434     debug  re16.sh    niina  R 8-23:36:27      1 ibc19
# DEBUG:sge:
# INFO:sge:Job 2981473 must be queued, running or being transferred
# ka 10 Na 400
# INFO:sge:Waiting for jobids [2981473] to finish
# DEBUG:sge:             JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
# DEBUG:sge:           2754893     debug job_01.s    niina  R 9-02:40:34      1 ibc01
# DEBUG:sge:           2754894     debug job_08.s    niina  R 9-02:40:34      1 ibc01
# DEBUG:sge:           2754895     debug job_09.s    niina  R 9-02:40:34      1 ibc01
# DEBUG:sge:           2754897     debug job_16.s    niina  R 9-02:40:34      1 ibc01
# DEBUG:sge:           2762398     debug plane_01    niina  R 9-00:41:07      1 ibc04
# DEBUG:sge:           2762399     debug plane_02    niina  R 9-00:41:07      1 ibc04
# DEBUG:sge:           2762400     debug plane_03    niina  R 9-00:41:07      1 ibc06
# DEBUG:sge:           2762401     debug plane_04    niina  R 9-00:41:07      1 ibc06
# DEBUG:sge:           2762402     debug plane_05    niina  R 9-00:41:07      1 ibc06
# DEBUG:sge:           2762403     debug plane_06    niina  R 9-00:41:07      1 ibc19
# DEBUG:sge:           2762404     debug plane_07    niina  R 9-00:41:07      1 ibc19
# DEBUG:sge:           2762405     debug plane_08    niina  R 9-00:41:07      1 ibc19
# DEBUG:sge:           2762406     debug plane_09    niina  R 9-00:41:07      1 ibc18
# DEBUG:sge:           2762407     debug plane_10    niina  R 9-00:41:07      1 ibc18
# DEBUG:sge:           2762408     debug plane_11    niina  R 9-00:41:07      1 ibc18
# DEBUG:sge:           2762409     debug plane_12    niina  R 9-00:41:07      1 ibc18
# DEBUG:sge:           2762411     debug plane_14    niina  R 9-00:41:07      1 ibc18
# DEBUG:sge:           2762412     debug plane_15    niina  R 9-00:41:07      1 ibc18
# DEBUG:sge:           2762413     debug plane_16    niina  R 9-00:41:07      1 ibc17
# DEBUG:sge:           2765414     debug plane_17    niina  R 9-00:10:34      1 ibc18
# DEBUG:sge:           2765415     debug plane_18    niina  R 9-00:10:34      1 ibc18
# DEBUG:sge:           2765416     debug plane_19    niina  R 9-00:10:34      1 ibc18
# DEBUG:sge:           2765417     debug plane_20    niina  R 9-00:10:34      1 ibc18
# DEBUG:sge:           2765418     debug plane_21    niina  R 9-00:10:34      1 ibc18
# DEBUG:sge:           2765419     debug plane_22    niina  R 9-00:10:34      1 ibc18
# DEBUG:sge:           2765420     debug plane_23    niina  R 9-00:10:34      1 ibc18
# DEBUG:sge:           2765421     debug plane_24    niina  R 9-00:10:33      1 ibc18
# DEBUG:sge:           2765422     debug plane_25    niina  R 9-00:10:33      1 ibc18
# DEBUG:sge:           2765423     debug plane_26    niina  R 9-00:10:33      1 ibc19
# DEBUG:sge:           2765424     debug plane_27    niina  R 9-00:10:33      1 ibc19
# DEBUG:sge:           2765425     debug plane_28    niina  R 9-00:10:33      1 ibc19
# DEBUG:sge:           2765426     debug plane_29    niina  R 9-00:10:33      1 ibc19
# DEBUG:sge:           2765427     debug plane_30    niina  R 9-00:10:33      1 ibc19
# DEBUG:sge:           2765428     debug plane_31    niina  R 9-00:10:33      1 ibc19
# DEBUG:sge:           2765429     debug plane_32    niina  R 9-00:10:33      1 ibc19
# DEBUG:sge:           2765430     debug  re01.sh    niina  R 8-23:36:50      1 ibc19
# DEBUG:sge:           2765431     debug  re08.sh    niina  R 8-23:36:44      1 ibc19
# DEBUG:sge:           2765432     debug  re09.sh    niina  R 8-23:36:41      1 ibc19
# DEBUG:sge:           2765433     debug  re14.sh    niina  R 8-23:36:38      1 ibc19
# DEBUG:sge:           2765434     debug  re16.sh    niina  R 8-23:36:38      1 ibc19
# DEBUG:sge:
# actual A 2.5495787887413877, V8.118717218871465,Ns29440,td1.6666666666666667e-05
# DEBUG:matplotlib.backends:backend module://ipykernel.pylab.backend_inline version unknown
# finish

# %%
from math import sqrt,pi
import numpy as np
from scipy.special import erfc,erfcx
D=1
def ST(ka,D,t): #from wellmixed theory (smoldyn2009)
    h = ka/D
    B=h*np.sqrt(D*t)
    return (erfcx(B)-1+2*h*np.sqrt(D*t/pi))

def stheory(ka,tt): #from k(t)1D
    h = float(ka/D)
    E=D*h*h*tt
    return -D*(np.exp(E)*erfc(np.sqrt(E))-1)

def rev(ka,kd,t,D):#reversible (smoldyn appendix)
    assert(ka*ka>4*D*kd)
    c1=(ka-np.sqrt(ka*ka-4*D*kd))*np.sqrt(t)/2/sqrt(D)
    c2=(ka+np.sqrt(ka*ka-4*D*kd))*np.sqrt(t)/2/sqrt(D)
    return t*ka*(c2*(1-erfcx(c1))+c1*(erfcx(c2)-1))/(c1*c2*(c2-c1))

def profile(ka,D,x,t): #smodlyn eq50
    B=x/(2*np.sqrt(D*t))
    return erfc(x/B)-np.exp(ka*x/D+ka*ka*t/D)*erfc(x/B+ka*np.sqrt(t/D))

#viz.plot_number_observer(obss[0])
#viz.plot_number_observer(obss[1])
#kfac=kfacs[0]
def run():
    #for i,ka in enumerate(kas):
    for i,rm in enumerate(rms):
        actualA = As[i]
        T=TT[i]
        Nt=NTs[i]
        st=Stds[i]
        h = ka/D
        conc = NA/Vs[i]
        Ns = Nss[i]
        print('ka={},rm={},actualA={:.4f},conc={:.4f},Ns={}'.format(ka,rm,actualA,conc,Ns))
        #print('N',NA,kfac)
        plt.title('D='+str(D)+'rm'+str(rm)+'simrun='+str(simrun))
        #plt.errorbar(T,(NA-Nt),st,label='sim rv='+str(rm))
        plt.plot(T,(NA-Nt),'.',label='sim,ka='+str(ka)+'rm='+str(rm))
        #plt.semilogx(tlogs,1-Area*2*(ST(ka,D,tlogs))/Vol,label='wellmix')
        plt.plot(T,2*conc*actualA*ST(ka,D,T)/h,label='wellmix theory'+str(rm))
        plt.plot(T,2*conc*actualA*rev(ka,kd,T,D),label='wellmix theory'+str(rm))
        #plt.semilogx(T[i],NA*2*Area*ST(ka,T[i])/Vol,label='wellmix')
        #plt.plot(T[i],stheory(ka,T[i]),'--',label='1D_CK'+str(kfac))
        plt.legend()
        #plt.ylim(0,1.5)
        #tt=np.logspace(-3,0,30)
        plt.ylabel('No surface molecule')
    #plt.xlim(1.6,2)
    ylast=(NA-Nt)[-1]
    #plt.ylim(ylast-5,ylast+5)
    #plt.ylim(35,46)

# %%
run()#irreversible n reversible
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in true_divide
# DEBUG:matplotlib.font_manager:findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('/usr/local/lib/python3.5/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000
# DEBUG:matplotlib.font_manager:findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0 to DejaVu Sans ('/usr/local/lib/python3.5/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000
# ka=10,rm=0.005,actualA=2.5496,conc=49.2689,Ns=29440

# %%
from ecell4 import *
# %matplotlib inline
import numpy as np
import math
import sys
from math import sqrt
import matplotlib.pyplot as plt
from ecell4.extra import ensemble
import numpy as np
from math import pi
def wrap(job,job_id,task_id):
    def singlerun(ka,kd,NA,L,run,duration,rm):
        import numpy as np
        D=1
        rng = GSLRandomNumberGenerator()
        rng.seed(run)   
        voxelr=rm    
        LL=4*L
        td =(2*voxelr)**2/(6*D)
        ori = Real3(LL*0.5,0,0)
        unit0 = Real3(0,0,L)
        unit1 = Real3(0,L,0)        
        w = spatiocyte.SpatiocyteWorld(Real3(LL,L,L),voxelr,rng)
        size=tuple(w.calculate_shape(Real3(LL,L,L),voxelr))
        lx,ly,lz=w.actual_lengths()
        Ns = size[1]*size[2]
        Area= ly*lz
        V=ly*lz*lx
        if run==1:
            print('actual A {}, V{},Ns{},td{}'.format(Area,V,Ns,td))
        w.add_structure(Species('M'),PlanarSurface(ori,unit0,unit1))
        with species_attributes():
            A |  {'D': str(D), 'radius':str(voxelr)}
            B |  {'D': str(D), 'radius':str(voxelr),'location':'M'}

        with reaction_rules():#for spa and egfrd
            A + M > B | ka
            #B > A |kd
            #A+M>M | ka

        m2 = get_model()
        w.bind_to(m2)
        w.add_molecules(Species('A'), NA)
        sim = spatiocyte.SpatiocyteSimulator(w)
        sim.initialize()
        pid = [p[0] for p in w.list_particles_exact(Species('A'))]
        obs = FixedIntervalTrajectoryObserver(duration/2,pids=pid,resolve_boundary=False)
        #obs=FixedIntervalNumberObserver(td*500,['A'])
        sim.run(duration,obs)        
        #dat=[tuple(pos) for pos in obs.data()[0]]
        return [obs.data(),obs.t()]
    job.update({'run':task_id})
    out=singlerun(**job)
    return out

ka=10
kd=0
NA=1000
L=1
rm=0.005
dur=0.3
tt=np.arange(0,dur+dur/2,dur/2)
simrun=1000
#dat= singlerun(ka,kd,NA,L,10,dur,rm)
jobs = [{'ka':ka,'kd':kd,'NA':NA,'L':L,'duration':dur,'rm':rm}]
#res=ensemble.run_multiprocessing(wrap,jobs,n=simrun,nproc=60,modules=('numpy','ecell4','math'))[0]
res=ensemble.run_slurm(wrap,jobs,n=simrun,nproc=500,path='tmp',modules=('numpy','ecell4','math'),extra_args=['--exclude=ibc[02,12,27]'])[0]
res = np.array(res)
tt = res.T[1][0]
# Out:
# DEBUG:matplotlib.backends:backend module://ipykernel.pylab.backend_inline version unknown
# DEBUG:sge:Submitted batch job 2985097
# DEBUG:sge:             JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
# DEBUG:sge:2985097_[1-1000%50     debug sge-bmek     chew PD       0:00      1 (None)
# DEBUG:sge:           2754893     debug job_01.s    niina  R 10-00:31:46      1 ibc01
# DEBUG:sge:           2754894     debug job_08.s    niina  R 10-00:31:46      1 ibc01
# DEBUG:sge:           2754895     debug job_09.s    niina  R 10-00:31:46      1 ibc01
# DEBUG:sge:           2754897     debug job_16.s    niina  R 10-00:31:46      1 ibc01
# DEBUG:sge:           2762398     debug plane_01    niina  R 9-22:32:19      1 ibc04
# DEBUG:sge:           2762399     debug plane_02    niina  R 9-22:32:19      1 ibc04
# DEBUG:sge:           2762400     debug plane_03    niina  R 9-22:32:19      1 ibc06
# DEBUG:sge:           2762401     debug plane_04    niina  R 9-22:32:19      1 ibc06
# DEBUG:sge:           2762402     debug plane_05    niina  R 9-22:32:19      1 ibc06
# DEBUG:sge:           2762403     debug plane_06    niina  R 9-22:32:19      1 ibc19
# DEBUG:sge:           2762404     debug plane_07    niina  R 9-22:32:19      1 ibc19
# DEBUG:sge:           2762405     debug plane_08    niina  R 9-22:32:19      1 ibc19
# DEBUG:sge:           2762406     debug plane_09    niina  R 9-22:32:19      1 ibc18
# DEBUG:sge:           2762407     debug plane_10    niina  R 9-22:32:19      1 ibc18
# DEBUG:sge:           2762408     debug plane_11    niina  R 9-22:32:19      1 ibc18
# DEBUG:sge:           2762409     debug plane_12    niina  R 9-22:32:19      1 ibc18
# DEBUG:sge:           2762411     debug plane_14    niina  R 9-22:32:19      1 ibc18
# DEBUG:sge:           2762412     debug plane_15    niina  R 9-22:32:19      1 ibc18
# DEBUG:sge:           2762413     debug plane_16    niina  R 9-22:32:19      1 ibc17
# DEBUG:sge:           2765414     debug plane_17    niina  R 9-22:01:46      1 ibc18
# DEBUG:sge:           2765415     debug plane_18    niina  R 9-22:01:46      1 ibc18
# DEBUG:sge:           2765416     debug plane_19    niina  R 9-22:01:46      1 ibc18
# DEBUG:sge:           2765417     debug plane_20    niina  R 9-22:01:46      1 ibc18
# DEBUG:sge:           2765418     debug plane_21    niina  R 9-22:01:46      1 ibc18
# DEBUG:sge:           2765419     debug plane_22    niina  R 9-22:01:46      1 ibc18
# DEBUG:sge:           2765420     debug plane_23    niina  R 9-22:01:46      1 ibc18
# DEBUG:sge:           2765421     debug plane_24    niina  R 9-22:01:45      1 ibc18
# DEBUG:sge:           2765422     debug plane_25    niina  R 9-22:01:45      1 ibc18
# DEBUG:sge:           2765423     debug plane_26    niina  R 9-22:01:45      1 ibc19
# DEBUG:sge:           2765424     debug plane_27    niina  R 9-22:01:45      1 ibc19
# DEBUG:sge:           2765425     debug plane_28    niina  R 9-22:01:45      1 ibc19
# DEBUG:sge:           2765426     debug plane_29    niina  R 9-22:01:45      1 ibc19
# DEBUG:sge:           2765427     debug plane_30    niina  R 9-22:01:45      1 ibc19
# DEBUG:sge:           2765428     debug plane_31    niina  R 9-22:01:45      1 ibc19
# DEBUG:sge:           2765429     debug plane_32    niina  R 9-22:01:45      1 ibc19
# DEBUG:sge:           2765430     debug  re01.sh    niina  R 9-21:28:02      1 ibc19
# DEBUG:sge:           2765431     debug  re08.sh    niina  R 9-21:27:56      1 ibc19
# DEBUG:sge:           2765432     debug  re09.sh    niina  R 9-21:27:53      1 ibc19
# DEBUG:sge:           2765433     debug  re14.sh    niina  R 9-21:27:50      1 ibc19
# DEBUG:sge:           2765434     debug  re16.sh    niina  R 9-21:27:50      1 ibc19
# DEBUG:sge:
# INFO:sge:Job 2985097 must be queued, running or being transferred
# INFO:sge:Waiting for jobids [2985097] to finish
# DEBUG:sge:             JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
# DEBUG:sge:2985097_[345-1000%     debug sge-bmek     chew PD       0:00      1 (None)
# DEBUG:sge:           2754893     debug job_01.s    niina  R 10-00:31:56      1 ibc01
# DEBUG:sge:           2754894     debug job_08.s    niina  R 10-00:31:56      1 ibc01
# DEBUG:sge:           2754895     debug job_09.s    niina  R 10-00:31:56      1 ibc01
# DEBUG:sge:           2754897     debug job_16.s    niina  R 10-00:31:56      1 ibc01
# DEBUG:sge:           2762398     debug plane_01    niina  R 9-22:32:29      1 ibc04
# DEBUG:sge:           2762399     debug plane_02    niina  R 9-22:32:29      1 ibc04
# DEBUG:sge:           2762400     debug plane_03    niina  R 9-22:32:29      1 ibc06
# DEBUG:sge:           2762401     debug plane_04    niina  R 9-22:32:29      1 ibc06
# DEBUG:sge:           2762402     debug plane_05    niina  R 9-22:32:29      1 ibc06
# DEBUG:sge:           2762403     debug plane_06    niina  R 9-22:32:29      1 ibc19
# DEBUG:sge:           2762404     debug plane_07    niina  R 9-22:32:29      1 ibc19
# DEBUG:sge:           2762405     debug plane_08    niina  R 9-22:32:29      1 ibc19
# DEBUG:sge:           2762406     debug plane_09    niina  R 9-22:32:29      1 ibc18
# DEBUG:sge:           2762407     debug plane_10    niina  R 9-22:32:29      1 ibc18
# DEBUG:sge:           2762408     debug plane_11    niina  R 9-22:32:29      1 ibc18
# DEBUG:sge:           2762409     debug plane_12    niina  R 9-22:32:29      1 ibc18
# DEBUG:sge:           2762411     debug plane_14    niina  R 9-22:32:29      1 ibc18
# DEBUG:sge:           2762412     debug plane_15    niina  R 9-22:32:29      1 ibc18
# DEBUG:sge:           2762413     debug plane_16    niina  R 9-22:32:29      1 ibc17
# DEBUG:sge:           2765414     debug plane_17    niina  R 9-22:01:56      1 ibc18
# DEBUG:sge:           2765415     debug plane_18    niina  R 9-22:01:56      1 ibc18
# DEBUG:sge:           2765416     debug plane_19    niina  R 9-22:01:56      1 ibc18
# DEBUG:sge:           2765417     debug plane_20    niina  R 9-22:01:56      1 ibc18
# DEBUG:sge:           2765418     debug plane_21    niina  R 9-22:01:56      1 ibc18
# DEBUG:sge:           2765419     debug plane_22    niina  R 9-22:01:56      1 ibc18
# DEBUG:sge:           2765420     debug plane_23    niina  R 9-22:01:56      1 ibc18
# DEBUG:sge:           2765421     debug plane_24    niina  R 9-22:01:55      1 ibc18
# DEBUG:sge:           2765422     debug plane_25    niina  R 9-22:01:55      1 ibc18
# DEBUG:sge:           2765423     debug plane_26    niina  R 9-22:01:55      1 ibc19
# DEBUG:sge:           2765424     debug plane_27    niina  R 9-22:01:55      1 ibc19
# DEBUG:sge:           2765425     debug plane_28    niina  R 9-22:01:55      1 ibc19
# DEBUG:sge:           2765426     debug plane_29    niina  R 9-22:01:55      1 ibc19
# DEBUG:sge:           2765427     debug plane_30    niina  R 9-22:01:55      1 ibc19
# DEBUG:sge:           2765428     debug plane_31    niina  R 9-22:01:55      1 ibc19
# DEBUG:sge:           2765429     debug plane_32    niina  R 9-22:01:55      1 ibc19
# DEBUG:sge:        2985097_71     debug sge-bmek     chew  R       0:10      1 ibc03
# DEBUG:sge:        2985097_72     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_73     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_74     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_75     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_76     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_77     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_78     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_79     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_80     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_81     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_82     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_83     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_84     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_85     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_86     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_87     debug sge-bmek     chew  R       0:10      1 ibc05
# DEBUG:sge:        2985097_88     debug sge-bmek     chew  R       0:10      1 ibc07
# DEBUG:sge:
# INFO:sge:Job 2985097 must be queued, running or being transferred
# INFO:sge:Waiting for jobids [2985097] to finish
# DEBUG:sge:             JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
# DEBUG:sge:2985097_[689-1000%     debug sge-bmek     chew PD       0:00      1 (Resources)
# DEBUG:sge:           2754893     debug job_01.s    niina  R 10-00:32:06      1 ibc01
# DEBUG:sge:           2754894     debug job_08.s    niina  R 10-00:32:06      1 ibc01
# DEBUG:sge:           2754895     debug job_09.s    niina  R 10-00:32:06      1 ibc01
# DEBUG:sge:           2754897     debug job_16.s    niina  R 10-00:32:06      1 ibc01
# DEBUG:sge:           2762398     debug plane_01    niina  R 9-22:32:39      1 ibc04
# DEBUG:sge:           2762399     debug plane_02    niina  R 9-22:32:39      1 ibc04
# DEBUG:sge:           2762400     debug plane_03    niina  R 9-22:32:39      1 ibc06
# DEBUG:sge:           2762401     debug plane_04    niina  R 9-22:32:39      1 ibc06
# DEBUG:sge:           2762402     debug plane_05    niina  R 9-22:32:39      1 ibc06
# DEBUG:sge:           2762403     debug plane_06    niina  R 9-22:32:39      1 ibc19
# DEBUG:sge:           2762404     debug plane_07    niina  R 9-22:32:39      1 ibc19
# DEBUG:sge:           2762405     debug plane_08    niina  R 9-22:32:39      1 ibc19
# DEBUG:sge:           2762406     debug plane_09    niina  R 9-22:32:39      1 ibc18
# DEBUG:sge:           2762407     debug plane_10    niina  R 9-22:32:39      1 ibc18
# DEBUG:sge:           2762408     debug plane_11    niina  R 9-22:32:39      1 ibc18
# DEBUG:sge:           2762409     debug plane_12    niina  R 9-22:32:39      1 ibc18
# DEBUG:sge:           2762411     debug plane_14    niina  R 9-22:32:39      1 ibc18
# DEBUG:sge:           2762412     debug plane_15    niina  R 9-22:32:39      1 ibc18
# DEBUG:sge:           2762413     debug plane_16    niina  R 9-22:32:39      1 ibc17
# DEBUG:sge:           2765414     debug plane_17    niina  R 9-22:02:06      1 ibc18
# DEBUG:sge:           2765415     debug plane_18    niina  R 9-22:02:06      1 ibc18
# DEBUG:sge:           2765416     debug plane_19    niina  R 9-22:02:06      1 ibc18
# DEBUG:sge:           2765417     debug plane_20    niina  R 9-22:02:06      1 ibc18
# DEBUG:sge:           2765418     debug plane_21    niina  R 9-22:02:06      1 ibc18
# DEBUG:sge:           2765419     debug plane_22    niina  R 9-22:02:06      1 ibc18
# DEBUG:sge:           2765420     debug plane_23    niina  R 9-22:02:06      1 ibc18
# DEBUG:sge:           2765421     debug plane_24    niina  R 9-22:02:05      1 ibc18
# DEBUG:sge:           2765422     debug plane_25    niina  R 9-22:02:05      1 ibc18
# DEBUG:sge:           2765423     debug plane_26    niina  R 9-22:02:05      1 ibc19
# DEBUG:sge:           2765424     debug plane_27    niina  R 9-22:02:05      1 ibc19
# DEBUG:sge:           2765425     debug plane_28    niina  R 9-22:02:05      1 ibc19
# DEBUG:sge:           2765426     debug plane_29    niina  R 9-22:02:05      1 ibc19
# DEBUG:sge:           2765427     debug plane_30    niina  R 9-22:02:05      1 ibc19
# DEBUG:sge:           2765428     debug plane_31    niina  R 9-22:02:05      1 ibc19
# DEBUG:sge:           2765429     debug plane_32    niina  R 9-22:02:05      1 ibc19
# DEBUG:sge:           2765430     debug  re01.sh    niina  R 9-21:28:22      1 ibc19
# DEBUG:sge:           2765431     debug  re08.sh    niina  R 9-21:28:16      1 ibc19
# DEBUG:sge:           2765432     debug  re09.sh    niina  R 9-21:28:13      1 ibc19
# DEBUG:sge:           2765433     debug  re14.sh    niina  R 9-21:28:10      1 ibc19
# DEBUG:sge:           2765434     debug  re16.sh    niina  R 9-21:28:10      1 ibc19
# DEBUG:sge:       2985097_687     debug sge-bmek     chew  R       0:05      1 ibc04
# DEBUG:sge:       2985097_688     debug sge-bmek     chew  R       0:05      1 ibc04
# DEBUG:sge:       2985097_634     debug sge-bmek     chew  R       0:06      1 ibc10
# DEBUG:sge:       2985097_635     debug sge-bmek     chew  R       0:06      1 ibc26
# DEBUG:sge:       2985097_636     debug sge-bmek     chew  R       0:06      1 ibc22
# DEBUG:sge:       2985097_637     debug sge-bmek     chew  R       0:06      1 ibc28
# DEBUG:sge:       2985097_638     debug sge-bmek     chew  R       0:06      1 ibc28
# DEBUG:sge:       2985097_639     debug sge-bmek     chew  R       0:06      1 ibc28
# DEBUG:sge:       2985097_640     debug sge-bmek     chew  R       0:06      1 ibc28
# DEBUG:sge:       2985097_641     debug sge-bmek     chew  R       0:06      1 ibc28
# DEBUG:sge:       2985097_642     debug sge-bmek     chew  R       0:06      1 ibc28
# DEBUG:sge:       2985097_643     debug sge-bmek     chew  R       0:06      1 ibc28
# DEBUG:sge:       2985097_929     debug sge-bmek     chew  R       0:09      1 ibc20
# DEBUG:sge:       2985097_930     debug sge-bmek     chew  R       0:09      1 ibc20
# DEBUG:sge:       2985097_931     debug sge-bmek     chew  R       0:09      1 ibc20
# DEBUG:sge:       2985097_932     debug sge-bmek     chew  R       0:09      1 ibc20
# DEBUG:sge:       2985097_933     debug sge-bmek     chew  R       0:09      1 ibc20
# DEBUG:sge:       2985097_934     debug sge-bmek     chew  R       0:09      1 ibc20
# DEBUG:sge:       2985097_935     debug sge-bmek     chew  R       0:09      1 ibc20
# DEBUG:sge:       2985097_936     debug sge-bmek     chew  R       0:09      1 ibc20
# DEBUG:sge:       2985097_937     debug sge-bmek     chew  R       0:09      1 ibc20
# DEBUG:sge:
# INFO:sge:Job 2985097 must be queued, running or being transferred
# INFO:sge:Waiting for jobids [2985097] to finish
# DEBUG:sge:             JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
# DEBUG:sge:           2754893     debug job_01.s    niina  R 10-00:32:27      1 ibc01
# DEBUG:sge:           2754894     debug job_08.s    niina  R 10-00:32:27      1 ibc01
# DEBUG:sge:           2754895     debug job_09.s    niina  R 10-00:32:27      1 ibc01
# DEBUG:sge:           2754897     debug job_16.s    niina  R 10-00:32:27      1 ibc01
# DEBUG:sge:           2762398     debug plane_01    niina  R 9-22:33:00      1 ibc04
# DEBUG:sge:           2762399     debug plane_02    niina  R 9-22:33:00      1 ibc04
# DEBUG:sge:           2762400     debug plane_03    niina  R 9-22:33:00      1 ibc06
# DEBUG:sge:           2762401     debug plane_04    niina  R 9-22:33:00      1 ibc06
# DEBUG:sge:           2762402     debug plane_05    niina  R 9-22:33:00      1 ibc06
# DEBUG:sge:           2762403     debug plane_06    niina  R 9-22:33:00      1 ibc19
# DEBUG:sge:           2762404     debug plane_07    niina  R 9-22:33:00      1 ibc19
# DEBUG:sge:           2762405     debug plane_08    niina  R 9-22:33:00      1 ibc19
# DEBUG:sge:           2762406     debug plane_09    niina  R 9-22:33:00      1 ibc18
# DEBUG:sge:           2762407     debug plane_10    niina  R 9-22:33:00      1 ibc18
# DEBUG:sge:           2762408     debug plane_11    niina  R 9-22:33:00      1 ibc18
# DEBUG:sge:           2762409     debug plane_12    niina  R 9-22:33:00      1 ibc18
# DEBUG:sge:           2762411     debug plane_14    niina  R 9-22:33:00      1 ibc18
# DEBUG:sge:           2762412     debug plane_15    niina  R 9-22:33:00      1 ibc18
# DEBUG:sge:           2762413     debug plane_16    niina  R 9-22:33:00      1 ibc17
# DEBUG:sge:           2765414     debug plane_17    niina  R 9-22:02:27      1 ibc18
# DEBUG:sge:           2765415     debug plane_18    niina  R 9-22:02:27      1 ibc18
# DEBUG:sge:           2765416     debug plane_19    niina  R 9-22:02:27      1 ibc18
# DEBUG:sge:           2765417     debug plane_20    niina  R 9-22:02:27      1 ibc18
# DEBUG:sge:           2765418     debug plane_21    niina  R 9-22:02:27      1 ibc18
# DEBUG:sge:           2765419     debug plane_22    niina  R 9-22:02:27      1 ibc18
# DEBUG:sge:           2765420     debug plane_23    niina  R 9-22:02:27      1 ibc18
# DEBUG:sge:           2765421     debug plane_24    niina  R 9-22:02:26      1 ibc18
# DEBUG:sge:           2765422     debug plane_25    niina  R 9-22:02:26      1 ibc18
# DEBUG:sge:           2765423     debug plane_26    niina  R 9-22:02:26      1 ibc19
# DEBUG:sge:           2765424     debug plane_27    niina  R 9-22:02:26      1 ibc19
# DEBUG:sge:           2765425     debug plane_28    niina  R 9-22:02:26      1 ibc19
# DEBUG:sge:           2765426     debug plane_29    niina  R 9-22:02:26      1 ibc19
# DEBUG:sge:           2765427     debug plane_30    niina  R 9-22:02:26      1 ibc19
# DEBUG:sge:           2765428     debug plane_31    niina  R 9-22:02:26      1 ibc19
# DEBUG:sge:           2765429     debug plane_32    niina  R 9-22:02:26      1 ibc19
# DEBUG:sge:           2765430     debug  re01.sh    niina  R 9-21:28:43      1 ibc19
# DEBUG:sge:           2765431     debug  re08.sh    niina  R 9-21:28:37      1 ibc19
# DEBUG:sge:           2765432     debug  re09.sh    niina  R 9-21:28:34      1 ibc19
# DEBUG:sge:           2765433     debug  re14.sh    niina  R 9-21:28:31      1 ibc19
# DEBUG:sge:           2765434     debug  re16.sh    niina  R 9-21:28:31      1 ibc19
# DEBUG:sge:
# actual A 1.0246812577577478, V4.116311818019621,Ns11832,td1.6666666666666667e-05

# %%
def profile(ka,D,x,t): #smodlyn eq50
    A=erfc(x/(2*np.sqrt(D*t)))
    C=np.exp(ka*x/D+ka*ka*t/D)
    E=erfc(x/(2*np.sqrt(D*t))+ka*np.sqrt(t/D))
    return A-C*E

plt.figure(figsize=(10,8))
LL=4*L
D=1
print('L',L,'LL',LL,'plane at ',LL*0.5)
VOL=L*L*LL
conc=NA/VOL
print('conc',conc)
bins = 29#int(LL/(2*rm*20))
print('bins',bins)
clrs=['r','g','c']
for i,t in enumerate(tt):#time loop
    c=clrs[i]
    X=[]
    for dt in res.T[0]:#iteration loop
        for d in dt:#particle loop
            try :
                X.append(tuple(d[i])[0])
            except IndexError: pass
    fq,be = np.histogram(X,bins=bins)#,range=(0,LL))
    mp = (be[1:]+be[:-1])*0.5
    width = be[1]-be[0]
    vol=L*L*width    
    #print(np.sum(fq)/simrun)
    fq=fq/simrun/vol
    #print(np.sum(fq))
    idx = mp>=2
    mp=mp[idx]-2
    fq=fq[idx]
    plt.plot(mp,fq,'o',c=c,label='t={:.3f}'.format(t))
    smoothx = np.linspace(1e-3,mp[-1],100)
    pp = conc*(1-profile(ka,D,smoothx,t))
    plt.plot(smoothx,pp,c=c,label=str(t))
plt.legend()
#print(mp)
plt.ylim(0,conc*1.1)
plt.ylabel('conc')
plt.xlabel('x')
plt.title('absorbing plane at 0')
# Out:
# L 1 LL 4 plane at  2.0
# conc 250.0
# bins 29
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# Text(0.5,1,'absorbing plane at 0')

# %%
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# Text(0.5,0,'x')

# %%
ka=85.9
kd=276
D=5
conc=10000
area=1
assert ka*ka>4*D*kd, 'ka*ka='+str(ka*ka)+',4*D*kd='+str(4*D*kd)
t=np.linspace(0,100,100)*1e-3
cc=area*rev(ka,kd,t,D,conc)
ca = area*ST(ka,D,t)*D*conc/ka
plt.plot(t,cc,'--')
plt.plot(t,ca,'-')
plt.ylim(0,7000)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in true_divide
# (0, 7000)

# %%
run()
# Out:
# ka=10,rm=0.003,actualA=2.5377,conc=49.5000,Ns=81396
# ka=10,rm=0.008,actualA=2.5717,conc=48.7941,Ns=11600

# %%
run()
# Out:
# ka=10,rm=0.005,actualA=2.5496,conc=49.2689,Ns=29440

# %%
run()
# Out:
# ka=0.1,rm=0.008,actualA=2.5717,conc=48.7941,Ns=11600

# %%
run()
# Out:
# ka=0.1,rm=0.003,actualA=2.5377,conc=49.5000,Ns=81396

# %%
run()
# Out:
# ka=0.1,rm=0.005,actualA=2.5496,conc=49.2689,Ns=29440

# %%
run()
# Out:
# ka=0.1,rm=0.005,actualA=4.0585,conc=6.1335,Ns=46864
# 79.0607
# ka=0.1,rm=0.01,actualA=4.0987,conc=6.0734,Ns=11832
# 79.0471

# %%
run()
# Out:
# DEBUG:matplotlib.font_manager:findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('/usr/local/lib/python3.5/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000
# DEBUG:matplotlib.font_manager:findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0 to DejaVu Sans ('/usr/local/lib/python3.5/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000
# ka=0.1,rm=0.005,actualA=4.0585,conc=49.0682,Ns=46864

# %%
run()
# Out:
# ka=0.1,rm=0.005,actualA=4.0585,conc=49.0682,Ns=46864

# %%
run()
# Out:
# ka=0.1,rm=0.005,actualA=4.0585,conc=49.0682,Ns=46864
# ka=0.1,rm=0.01,actualA=4.0987,conc=48.1954,Ns=11832

# %%
run()
# Out:
# 0 0.1 0.005
# 1 10.0 0.005

# %%
run()
# Out:
# 0 0.1 0.003
# 1 0.1 0.005
# 2 0.1 0.01

# %%
run()
# Out:
# 0 10 0.003
# 1 10 0.005
# 2 10 0.01

# %%
run()
# Out:
# 0 0.010000000000000002
# 1 1.0

# %%
run()
# Out:
# 0 1.0
# 1 100.0

# %%
run()
# Out:
# 0 0.1
# 1 10.0

# %%
from math import sqrt,pi
from scipy.special import erfc

C=1./L
tt=np.logspace(-3,0,30)
kfacs=[10]
for i,kfac in enumerate(kfacs):
    #plt.semilogx(T[i],(1-Nlog[i]/NA),'.',label=kfacs[i])
    plt.semilogx(T[i],L*L*stheory(C,kfac,T[i]),label=ka)
    plt.semilogx(T[i],2*L*L*ST(kfac,L**3,T[i]))
plt.legend()
plt.ylim(0,1.5)
# Out:
# (0, 1.5)

# %%
stheory(C,0.1,1e-3)
# Out:
# 0.01840289424133198

# %%
from ecell4 import *
# %matplotlib inline
import numpy as np
import math
import sys
from math import sqrt
import matplotlib.pyplot as plt
from ecell4.extra import ensemble
import numpy as np
from math import pi

def wrap(job,job_id,task_id):
    def singlerun(ka,NA,L,run,duration,rm):
        import numpy as np
        D=1
        rng = GSLRandomNumberGenerator()
        rng.seed(run)   
        voxelr=rm    
        td =(2*voxelr)**2/(6*D)
        ori = Real3(0.5*L,0,0)
        #ori = Real3(0.5*L*2,0,0)
        unit0 = Real3(0,0,L)
        unit1 = Real3(0,L,0)        
        w = spatiocyte.SpatiocyteWorld(Real3(L,L,L),voxelr,rng)
        #w = spatiocyte.SpatiocyteWorld(Real3(L*2,L,L),voxelr,rng)
        size=tuple(w.calculate_shape(Real3(L,L,L),voxelr))
        lx,ly,lz=w.actual_lengths()
        Ns = size[1]*size[2]
        Area= ly*lz
        V=ly*lz*lx
        if run==1:
            print('actual A {}, V{},Ns{},td{}'.format(Area,V,Ns,td))
        w.add_structure(Species('M'),PlanarSurface(ori,unit0,unit1))
        with species_attributes():
            A |  {'D': str(D), 'radius':str(voxelr)}
            #B |  {'D': str(0), 'radius':str(voxelr),'location':'M'}

        with reaction_rules():#for spa and egfrd
            #A + M > B | ka
            A+M>M | ka

        m2 = get_model()
        w.bind_to(m2)
        
        
        w.add_molecules(Species('A'), NA)
        sim = spatiocyte.SpatiocyteSimulator(w)
        sim.initialize()
        #obs=FixedIntervalNumberObserver(td*1000,['A'])
        #sim.run(duration,obs)        
        #tlogs,nalog=np.array(obs.data()).T        
        tlogint = td*1000
        tlog=tlogint
        nalog=[]
        tlogs=[]
        prvA = NA
        nB=0
        while sim.t()<duration:
            cA = w.num_particles_exact(Species('A'))
            chg = abs(cA-prvA)
            if (chg!=0): 
                nB +=chg
                #print(chg)
                #w.add_molecules(Species('A'), chg)
                #prvA=cA+chg
                prvA=cA
            if sim.t()>=tlog:
                tlogs.append(sim.t())                              
                nalog.append(nB)
                tlog+=tlogint
            sim.step()        
        #assert(cA==NA)
        tlogs=np.array(tlogs)
        nalog=np.array(nalog)
        return tlogs,nalog,V,Area,Ns
    job.update({'run':task_id})
    out=singlerun(**job)
    return out


L=2.
dur=2
NA = 400
rm=0.005
simrun = 100
ka=0.1

TT=[]
NTs=[]
Vs = []
As=[]
Nss=[]
Stds=[]
print('ka',ka,'Na',NA)
rms=[0.005]
#for ka in kas:
for rm in rms:
    jobs = [{'ka':ka,'NA':NA,'L':L,'duration':dur,'rm':rm}]
    #res=ensemble.run_multiprocessing(wrap,jobs,n=simrun,nproc=60,modules=('numpy','ecell4','math'))[0]
    res=ensemble.run_slurm(wrap,jobs,n=simrun,nproc=500,path='tmp',modules=('numpy','ecell4','math'),extra_args=['--exclude=ibc[02,12,27]'])[0]
    res = np.array(res)
    T = res.T[0][0]   
    #print(res.T[1])
    #Nt = np.mean(res.T[1])
    Nt = sum(res.T[1])/simrun
    #print(Nt)
    std = np.std(res.T[1])
    Vs.append(res.T[2][0])
    As.append(res.T[3][0])
    Nss.append(res.T[4][0])
    TT.append(T)
    NTs.append(Nt)
    Stds.append(std)
print('finish')

# %%
def ST(ka,D,t): #from wellmixed theory (smoldyn2009)
    h = ka/D
    B=h*np.sqrt(D*t)
    return (erfcx(B)-1+2*h*np.sqrt(D*t/pi))

# %%
from ecell4 import *
# %matplotlib inline
import numpy as np
import math
import sys
from math import sqrt
import matplotlib.pyplot as plt
from ecell4.extra import ensemble
import numpy as np
from math import pi

def wrap(job,job_id,task_id):
    def singlerun(ka,NA,L,run,duration):
        import numpy as np
        rng = GSLRandomNumberGenerator()
        rng.seed(run)
        rm = 0.005
        R=2*rm
        voxelr=rm
        D = 1.
        td =(2*voxelr)**2/(4*D)
        #print('td',td)
        H = 3*voxelr*2
        ori = Real3(0.5*H,0,0)
        unit0 = Real3(0,0,L)
        unit1 = Real3(0,L,0)        
        w = spatiocyte.SpatiocyteWorld(Real3(H,L,L),voxelr,rng)
        lx,ly,lz=w.actual_lengths()
        Area= ly*lz

        with species_attributes():
            B |  {'D': str(D), 'radius':str(voxelr),'location':'M'}
            A |  {'D': str(D), 'radius':str(voxelr)}

        with reaction_rules():#for spa and egfrd
            A + M > B | ka

        m2 = get_model()
        w.bind_to(m2)
        w.add_structure(Species('M'),PlanarSurface(ori,unit0,unit1))
        w.add_molecules(Species('A'), NA)
        sim = spatiocyte.SpatiocyteSimulator(w)
        sim.initialize()
        obs = NumberObserver(('A','B'))
        #obs=FixedIntervalNumberObserver(td,'A')
        #sim.run(duration)
        sim.run(duration,obs)        
        #print('ka',ka,'evaluated ka',res*Area/sim.dt()/NA/NB)        
        #obs=[0]
        tlogs,nalog,nblog=np.array(obs.data()).T
        return tlogs,nalog,nblog
    job.update({'run':task_id})
    out=singlerun(**job)
    return out

NA=500
L=1
ka = 1
dur=2

simrun=1

jobs=[{'ka':ka,'L':L,'NA':NA,'duration':dur}]
res=ensemble.run_multiprocessing(wrap,jobs,n=simrun,nproc=60,modules=('numpy','ecell4','math'))[0]
print('finish')
# Out:
# finish

# %%
#name = '/home/chew/outputdata/ec3adsoprtionk01.csv'
name = '/home/chew/spatiocyte_example/accuracy/3D_to_2D_planar_adsorption/3D_lattice_2D_off_lattice/IterateLogk01.csv'
t,nt= (np.loadtxt(name,delimiter=',',skiprows=1)).T
NA = 10000
L=100
Vol=998785#L**3
Area=10023.9#L**2
print(Vol,Area)
conc = NA/Vol
ka=0.1
D=1
h=ka/D
print('conc={:.4f}'.format(conc))
plt.plot(t,conc*Area*ST(ka,D,t)/h,label='wellmix theory')
plt.plot(t,nt,'--',label='sim')
plt.legend()
# Out:
# 998785 10023.9
# conc=0.0100

# %%
#name = '/home/chew/outputdata/ec3adsoprtionk01.csv'
name = '/home/chew/spatiocyte_example/accuracy/3D_to_2D_planar_adsorption/3D_lattice_2D_off_lattice/IterateLogk01.csv'
t,nt= (np.loadtxt(name,delimiter=',',skiprows=1)).T
NA = 100
L=2.
Vol=8.00374#L**3
Area=3.99636#L**2
print(Vol,Area)
conc = NA/Vol
ka=0.1
D=1
h=ka/D
print('conc={:.4f}'.format(conc))
plt.plot(t,2*conc*Area*ST(ka,D,t)/h,label='wellmix theory')
plt.plot(t,nt,'.',label='sim')
plt.legend()
# Out:
# 8.00374 3.99636
# conc=12.4942

# %%
3.39581e-15/1e-18
# Out:
# 3395.8099999999995

# %%
15**3
# Out:
# 3375

# %%
D=1
ka=1
rv=0.005
24*ka*rv/(6+3*sqrt(3)+2*sqrt(6)*D),ka*2*rv*sqrt(2)/sqrt(3)/D,ka*sqrt(2)/3/D/rv
# Out:
# (0.007455670489927411, 0.008164965809277261, 94.28090415820634)
