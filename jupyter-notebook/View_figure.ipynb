# %%
from IPython.display import Image
#name='/home/chew/ecellwork/figure/sturrock_birth_death_rm0.005_Nas5.png'
name='/home/chew/ecellwork/figure/sturrock_birth_death_rm0.005_Nas5_10k.png'
Image(filename=name)

# %%
from IPython.display import Image
#name='/home/chew/ecellwork/figure/sturrock_birth_death_rm0.05_Nas5.png'
name='/home/chew/ecellwork/figure/sturrock_birth_death_rm0.05_Nas5_10k.png'
Image(filename=name)

# %%
#name ='/home/chew/ecellwork/figure/sturrock_birth_death_rm0.005_Nas10.png'
#Image(filename=name)
